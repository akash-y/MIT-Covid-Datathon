# %%
#Importing Libraries
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('ACS_data.csv')

# %%
x=list(data.columns)
x
# Out:
# ['geo_id',
#  'do_date',
#  'total_pop',
#  'households',
#  'male_pop',
#  'female_pop',
#  'median_age',
#  'male_under_5',
#  'male_5_to_9',
#  'male_10_to_14',
#  'male_15_to_17',
#  'male_18_to_19',
#  'male_20',
#  'male_21',
#  'male_22_to_24',
#  'male_25_to_29',
#  'male_30_to_34',
#  'male_35_to_39',
#  'male_40_to_44',
#  'male_45_to_49',
#  'male_50_to_54',
#  'male_55_to_59',
#  'male_65_to_66',
#  'male_67_to_69',
#  'male_70_to_74',
#  'male_75_to_79',
#  'male_80_to_84',
#  'male_85_and_over',
#  'female_under_5',
#  'female_5_to_9',
#  'female_10_to_14',
#  'female_15_to_17',
#  'female_18_to_19',
#  'female_20',
#  'female_21',
#  'female_22_to_24',
#  'female_25_to_29',
#  'female_30_to_34',
#  'female_35_to_39',
#  'female_40_to_44',
#  'female_45_to_49',
#  'female_50_to_54',
#  'female_55_to_59',
#  'female_60_to_61',
#  'female_62_to_64',
#  'female_65_to_66',
#  'female_67_to_69',
#  'female_70_to_74',
#  'female_75_to_79',
#  'female_80_to_84',
# ...

# %%
data_sub = data[['geo_id','county_name','total_pop','households','male_pop','female_pop','median_age',
                'male_under_5','male_5_to_9','male_10_to_14','male_15_to_17',
                'male_18_to_19','male_20','male_21','male_22_to_24','male_25_to_29',
                'male_30_to_34','male_35_to_39','male_40_to_44','male_45_to_49','male_50_to_54','male_55_to_59',
                'male_65_to_66','male_67_to_69','male_70_to_74','male_75_to_79','male_80_to_84','male_85_and_over',
                'female_under_5','female_5_to_9','female_10_to_14','female_15_to_17','female_18_to_19','female_20',
                'female_21','female_22_to_24','female_25_to_29','female_30_to_34','female_35_to_39','female_40_to_44',
                'female_45_to_49','female_50_to_54','female_55_to_59','female_60_to_61','female_62_to_64','female_65_to_66',
                'female_67_to_69','female_70_to_74','female_75_to_79','female_80_to_84','worked_at_home','zip_code',
                'nonfamily_households','married_households','family_households']]

# %%
data_sub.dtypes
# Out:
# total_pop             int64
# households            int64
# male_pop              int64
# female_pop            int64
# median_age          float64
# male_under_5          int64
# male_5_to_9           int64
# male_10_to_14         int64
# male_15_to_17         int64
# male_18_to_19         int64
# male_20               int64
# male_21               int64
# male_22_to_24         int64
# male_25_to_29         int64
# male_30_to_34         int64
# male_35_to_39         int64
# male_40_to_44         int64
# male_45_to_49         int64
# male_50_to_54         int64
# male_55_to_59         int64
# male_65_to_66         int64
# male_67_to_69         int64
# male_70_to_74         int64
# male_75_to_79         int64
# male_80_to_84         int64
# male_85_and_over      int64
# female_under_5        int64
# female_5_to_9         int64
# female_10_to_14       int64
# female_15_to_17       int64
# female_18_to_19       int64
# female_20             int64
# female_21             int64
# ...

# %%
spatial_data = gpd.read_file('tl_2019_us_zcta510/tl_2019_us_zcta510.shp')
spatial_data.head()
# Out:
#   ZCTA5CE10 GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10    ALAND10  AWATER10  \
# 0     43451   43451        B5   G6350          S   63484186    157689
# 1     43452   43452        B5   G6350          S  121522304  13721730
# 2     43456   43456        B5   G6350          S    9320975   1003775
# 3     43457   43457        B5   G6350          S   48004681         0
# 4     43458   43458        B5   G6350          S    2573816     39915
#
#     INTPTLAT10    INTPTLON10  \
# 0  +41.3183010  -083.6174935
# 1  +41.5157923  -082.9809454
# 2  +41.6318300  -082.8393923
# 3  +41.2673301  -083.4274872
# 4  +41.5304461  -083.2133648
#
#                                             geometry
# 0  POLYGON ((-83.70873 41.32733, -83.70815 41.327...
# 1  POLYGON ((-83.08698 41.53780, -83.08256 41.537...
# 2  MULTIPOLYGON (((-82.83558 41.71082, -82.83515 ...
# 3  POLYGON ((-83.49650 41.25371, -83.48382 41.253...
# 4  POLYGON ((-83.22229 41.53102, -83.22228 41.532...
